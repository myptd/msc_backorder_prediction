# %%
from pathlib import Path
import pandas as pd

# Define the directory and pattern
directory = Path('output_training/phase2_dataset1_rus')
pattern = '*_performance.csv'

# List all matching files
csv_files = list(directory.glob(pattern))
classifer_names = [file.stem.split('_')[0] for file in csv_files]
# Read all CSV files and concatenate them into a single DataFrame

dataframes = [pd.read_csv(file) for file in csv_files]
df = pd.concat(dataframes, ignore_index=True)
df['classifer'] = classifer_names

# %%
classifer_names = [file.stem.split('_')[0] for file in csv_files]

# %%
#csv_files[0].stem.split('_')[0]

# %%
#df.columns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set style
sns.set_theme(style="whitegrid")

# Create figure
plt.figure(figsize=(10, 6))

# Transposed barplot (swap x and y)
sns.barplot(
    y="imbalance_handling", 
    x="auc_pr", 
    hue="classifer", 
    data=df, 
    palette="Set2", 
    edgecolor="black", 
    linewidth=1.2
)

# Titles and labels
#plt.title("AUC-PR by Classifier and Imbalance Handling Method", fontsize=14, fontweight="bold")
plt.ylabel("Imbalance Handling Method", fontsize=12)
plt.xlabel("AUC-PR", fontsize=12)

# Adjust legend (move outside the plot)
plt.legend(title="Classifier", fontsize=10, title_fontsize="11", loc="upper left", bbox_to_anchor=(1, 1), frameon=True)

# Improve y-ticks
plt.yticks(fontsize=10)

# Layout adjustment
plt.tight_layout()

plt.savefig("phase2_auc_pr_plot.pdf", format="pdf", bbox_inches="tight")

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set style
sns.set_theme(style="whitegrid")

# Create figure
plt.figure(figsize=(10, 6))

# Transposed barplot (swap x and y)
sns.barplot(
    y="imbalance_handling", 
    x="auc_roc", 
    hue="classifer", 
    data=df, 
    palette="Set2",  # Colorblind-friendly
    edgecolor="black", 
    linewidth=1.2
)

# Titles and labels
#plt.title("AUC-ROC by Classifier and Imbalance Handling Method", fontsize=14, fontweight="bold")
plt.ylabel("Imbalance Handling Method", fontsize=12)
plt.xlabel("AUC-ROC", fontsize=12)

# Adjust legend (move outside the plot)
plt.legend(title="Classifier", fontsize=10, title_fontsize="11", loc="upper left", bbox_to_anchor=(1, 1), frameon=True)

# Improve y-ticks
plt.yticks(fontsize=10)

# Layout adjustment
plt.tight_layout()

plt.savefig("phase2_auc_roc_plot.pdf", format="pdf", bbox_inches="tight")
# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set style
sns.set_theme(style="whitegrid")

# Create figure
plt.figure(figsize=(10, 6))

# Transposed barplot (swap x and y)
sns.barplot(
    y="imbalance_handling", 
    x="max_f1", 
    hue="classifer", 
    data=df, 
    palette="Set2",  # Colorblind-friendly
    edgecolor="black", 
    linewidth=1.2
)

# Titles and labels
#plt.title("Max F1 by Classifier and Imbalance Handling Method", fontsize=14, fontweight="bold")
plt.ylabel("Imbalance Handling Method", fontsize=12)
plt.xlabel("Max F1", fontsize=12)

# Adjust legend (move outside the plot)
plt.legend(title="Classifier", fontsize=10, title_fontsize="11", loc="upper left", bbox_to_anchor=(1, 1), frameon=True)

# Improve y-ticks
plt.yticks(fontsize=10)

# Layout adjustment
plt.tight_layout()

plt.savefig("phase2_maxf1_plot.pdf", format="pdf", bbox_inches="tight")

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set style
sns.set_theme(style="whitegrid")

# Create figure
plt.figure(figsize=(10, 6))

# Transposed barplot (swap x and y)
sns.barplot(
    y="imbalance_handling", 
    x="max_f05", 
    hue="classifer", 
    data=df, 
    palette="Set2",  # Colorblind-friendly
    edgecolor="black", 
    linewidth=1.2
)

# Titles and labels
#plt.title("Max F0.5 by Classifier and Imbalance Handling Method", fontsize=14, fontweight="bold")
plt.ylabel("Imbalance Handling Method", fontsize=12)
plt.xlabel("Max F0.5", fontsize=12)

# Adjust legend (move outside the plot)
plt.legend(title="Classifier", fontsize=10, title_fontsize="11", loc="upper left", bbox_to_anchor=(1, 1), frameon=True)

# Improve y-ticks
plt.yticks(fontsize=10)

# Layout adjustment
plt.tight_layout()

plt.savefig("phase2_maxf05_plot.pdf", format="pdf", bbox_inches="tight")

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set style
sns.set_theme(style="whitegrid")

# Create figure
plt.figure(figsize=(10, 6))

# Transposed barplot (swap x and y)
sns.barplot(
    y="imbalance_handling", 
    x="max_f2", 
    hue="classifer", 
    data=df, 
    palette="Set2",  # Colorblind-friendly
    edgecolor="black", 
    linewidth=1.2
)

# Titles and labels
#plt.title("Max F2 by Classifier and Imbalance Handling Method", fontsize=14, fontweight="bold")
plt.ylabel("Imbalance Handling Method", fontsize=12)
plt.xlabel("Max F2", fontsize=12)

# Adjust legend (move outside the plot)
plt.legend(title="Classifier", fontsize=10, title_fontsize="11", loc="upper left", bbox_to_anchor=(1, 1), frameon=True)

# Improve y-ticks
plt.yticks(fontsize=10)

# Layout adjustment
plt.tight_layout()

plt.savefig("phase2_maxf2_plot.pdf", format="pdf", bbox_inches="tight")

# Show plot
plt.show()

# %%
df.groupby('classifer')['auc_pr'].mean()
# Out:
# classifer
# AdaBoostClassifier        0.182865
# LogisticRegression        0.029719
# RandomForestClassifier    0.198814
# SVC                       0.041203
# XGBClassifier             0.184708
# Name: auc_pr, dtype: float64

# %%
df.groupby('imbalance_handling')['auc_pr'].mean()
# Out:
# imbalance_handling
# rus    0.127462
# Name: auc_pr, dtype: float64

# %%
df.groupby('imbalance_handling')['auc_roc'].mean()
# Out:
# imbalance_handling
# rus    0.848936
# Name: auc_roc, dtype: float64
